# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r"../data/raw/big_startup_success_dataset.csv")

# %%
# Convert Date Columns
date_columns = [
    "founded_at",
    "first_funding_at",
    "last_funding_at"
]

for column in date_columns:
    df[column] = pd.to_datetime(df[column],errors="coerce")

# %%
# Extract Year Columns
df["founded_year"] = df["founded_at"].dt.year
df["first_funding_year"] = df["first_funding_at"].dt.year
df["last_funding_year"] = df["last_funding_at"].dt.year

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66368 entries, 0 to 66367
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   permalink           66368 non-null  object
#  1   name                66367 non-null  object
#  2   homepage_url        61310 non-null  object
#  3   category_list       63220 non-null  object
#  4   funding_total_usd   66368 non-null  object
#  5   status              66368 non-null  object
#  6   country_code        59410 non-null  object
#  7   state_code          57821 non-null  object
#  8   region              58338 non-null  object
#  9   city                58340 non-null  object
#  10  funding_rounds      66368 non-null  int64
#  11  founded_at          51143 non-null  datetime64[ns]
#  12  first_funding_at    66341 non-null  datetime64[ns]
#  13  last_funding_at     66368 non-null  datetime64[ns]
#  14  founded_year        51143 non-null  float64
# ...

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# founded_year          15225
# founded_at            15225
# state_code             8547
# region                 8030
# city                   8028
# country_code           6958
# homepage_url           5058
# category_list          3148
# first_funding_at         27
# first_funding_year       27
# name                      1
# last_funding_at           0
# permalink                 0
# funding_rounds            0
# status                    0
# funding_total_usd         0
# last_funding_year         0
# dtype: int64

# %%
# Missing Percentage
missing_percentage = (df.isnull().mean()*100).sort_values(ascending=False)

missing_percentage
# Out:
# founded_year          22.940272
# founded_at            22.940272
# state_code            12.878194
# region                12.099204
# city                  12.096191
# country_code          10.483968
# homepage_url           7.621143
# category_list          4.743250
# first_funding_at       0.040682
# first_funding_year     0.040682
# name                   0.001507
# last_funding_at        0.000000
# permalink              0.000000
# funding_rounds         0.000000
# status                 0.000000
# funding_total_usd      0.000000
# last_funding_year      0.000000
# dtype: float64

# %%
# Duplicate Row Analysis
duplicate_rows = df.duplicated().sum()
print("Total Duplicate Rows :", duplicate_rows)
# Out:
# Total Duplicate Rows : 0

# %%
#  Unique Value Analysis
df.nunique().sort_values()
# Out:
# status                    4
# funding_rounds           19
# first_funding_year       40
# last_funding_year        41
# country_code            137
# founded_year            176
# state_code              311
# region                 1092
# founded_at             3974
# last_funding_at        4518
# first_funding_at       4814
# city                   5111
# funding_total_usd     18896
# category_list         27296
# homepage_url          61191
# name                  66102
# permalink             66368
# dtype: int64

# %%
# Complete Dataset Overview
df.describe(include="all")
# Out:
#                   permalink   name                homepage_url category_list  \
# count                 66368  66367                       61310         63220
# unique                66368  66102                       61191         27296
# top     /organization/-fame  Blink  http://www.askforoffer.com      Software
# freq                      1      4                           5          3995
# mean                    NaN    NaN                         NaN           NaN
# min                     NaN    NaN                         NaN           NaN
# 25%                     NaN    NaN                         NaN           NaN
# 50%                     NaN    NaN                         NaN           NaN
# 75%                     NaN    NaN                         NaN           NaN
# max                     NaN    NaN                         NaN           NaN
# std                     NaN    NaN                         NaN           NaN
#
# ...

# %%
df.head(20)
# df.tail(20)
# Out:
#                                    permalink                         name  \
# 0                        /organization/-fame                        #fame
# 1                     /organization/-qounter                     :Qounter
# 2        /organization/-the-one-of-them-inc-       (THE) ONE of THEM,Inc.
# 3                      /organization/0-6-com                      0-6.com
# 4             /organization/004-technologies             004 Technologies
# 5           /organization/01games-technology           01Games Technology
# 6        /organization/0ndine-biomedical-inc       Ondine Biomedical Inc.
# 7                       /organization/0xdata                       H2O.ai
# 8                            /organization/1                     One Inc.
# 9                  /organization/1-2-3-listo                  1,2,3 Listo
# 10                     /organization/1-4-all                      1-4 All
# 11            /organization/1-618-technology             1.618 Technology
# ...

# %%
df[df['funding_total_usd'] == '-'].shape
# Out:
# (12785, 17)

# %%
df["funding_total_usd"].value_counts().head(10)
# Out:
# funding_total_usd
# -           12785
# 1000000      1147
# 100000        983
# 500000        979
# 2000000       820
# 50000         767
# 40000         696
# 250000        645
# 10000000      633
# 1500000       619
# Name: count, dtype: int64

# %%
df["funding_total_usd"].dtype
# Out:
# dtype('O')

# %%
df["funding_total_usd"].str.contains(r"\$", na=False).sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Day-03: Initial Data Exploration & Data Quality Assessment
#
# ## Objective
#
# The goal of Day-03 was to understand the structure and quality of the startup dataset before starting the preprocessing phase.
#
# ---
#
# ##  Tasks Completed
#
# ### 1. Imported Required Libraries
# - NumPy
# - Pandas
#
# ### 2. Loaded the Dataset
# - Successfully loaded the Startup Success Dataset.
#
# ### 3. Converted Date Columns
# Converted the following columns into datetime format:
# - founded_at
# - first_funding_at
# - last_funding_at
#
# Invalid date values were converted into `NaT`.
#
# ### 4. Feature Engineering
# Extracted year information from datetime columns:
# - founded_year
# - first_funding_year
# - last_funding_year
#
# ### 5. Dataset Structure Analysis
# Performed dataset inspection using:
# - `df.info()`
#
# Checked:
# - Total rows
# - Total columns
# - Data types
# - Non-null values
# - Memory usage
#
# ### 6. Missing Value Analysis
# Calculated:
# - Missing value count
# - Missing value percentage
#
# ### 7. Duplicate Analysis
# Checked duplicate rows in the dataset.
#
# ### 8. Unique Value Analysis
# Calculated unique values for every feature.
#
# ### 9. Statistical Summary
# Generated descriptive statistics using:
#
# - Numerical Features
# - Categorical Features
#
# ### 10. Dataset Preview
# Inspected sample records using:
# - `head()`
#
# ### 11. Funding Column Investigation
# Performed an initial investigation on `funding_total_usd`.
#
# Checked:
# - Missing placeholders (`-`)
# - Currency symbols (`$`)
# - Datatype
# - Most frequent values
#
# ---
#
# # Key Findings
#
# - Date columns required datetime conversion.
# - New year-based features were successfully created.
# - Several columns contain missing values.
# - Dataset contains categorical and numerical features.
# - `funding_total_usd` requires cleaning before analysis.
# - Dataset quality assessment completed successfully.
#
# ---
#
# # Outcome
#
# The dataset has been successfully explored and understood.
#
# No preprocessing has been performed yet.
#
# The notebook is now ready for the data cleaning phase.
#
# ---
#
# # Next Step (Day-04)
#
# - Clean `funding_total_usd`
# - Handle missing values
# - Detect outliers
# - Perform feature-wise preprocessing
# - Start Univariate Analysis
